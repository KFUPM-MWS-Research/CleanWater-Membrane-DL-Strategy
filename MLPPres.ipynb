# %% [markdown]
# ## Import all the requiered libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import sklearn
import seaborn as sns

import torch
from torch.autograd import Variable
import torch.utils.data as Data
import torch.nn as nn

# %% [markdown]
# ## Explore and prepare the dataset

# %%
df = pd.read_csv("dataset/dataset_membrane_.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5216 entries, 0 to 5215
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   SW         5216 non-null   float64
#  1   MWCO       5216 non-null   int64
#  2   CA         5216 non-null   int64
#  3   ZP         5216 non-null   float64
#  4   Permeance  5216 non-null   float64
#  5   Rejection  5216 non-null   float64
# dtypes: float64(4), int64(2)
# memory usage: 244.6 KB

# %%
df
# Out:
#             SW  MWCO  CA    ZP  Permeance  Rejection
# 0     1.507780   350  87 -15.0  48.058984   0.742500
# 1     1.507780   350  87 -15.0  48.058984   0.351755
# 2     1.507780   350  87 -15.0  48.058984   0.364472
# 3     1.507780   350  87 -15.0  48.058984   0.232885
# 4     1.507780   350  87 -15.0  48.058984   0.098254
# ...        ...   ...  ..   ...        ...        ...
# 5211  1.888928   200  34 -15.0   3.121693   0.625072
# 5212  1.888928   200  34 -15.0   3.121693   0.011880
# 5213  1.888928   200  34 -15.0   3.121693   0.109433
# 5214  1.888928   200  34 -15.0   3.121693   0.481725
# 5215  1.888928   200  34 -15.0   3.121693   0.071627
#
# [5216 rows x 6 columns]

# %%
type(df['SW'][0])
# Out:
# numpy.float64

# %%
X = df.drop(['Permeance', 'Rejection'], axis=1)
y = df['Permeance']
y.head(5)
# Out:
# 0    48.058984
# 1    48.058984
# 2    48.058984
# 3    48.058984
# 4    48.058984
# Name: Permeance, dtype: float64

# %% [markdown]
# **Lets use Min Max Normalization to normalize all the seven features, transforming their values into a scale between 0 and 1.**

# %%
def normalize(dataset):
    data_normalized = ((dataset-dataset.min())/(dataset.max()-dataset.min()))
    return data_normalized

# %%
features = normalize(df)
features
# Out:
#             SW      MWCO   CA        ZP  Permeance  Rejection
# 0     0.454667  0.571429  1.0  0.616438   0.741910   0.817718
# 1     0.454667  0.571429  1.0  0.616438   0.741910   0.541114
# 2     0.454667  0.571429  1.0  0.616438   0.741910   0.550116
# 3     0.454667  0.571429  1.0  0.616438   0.741910   0.456967
# 4     0.454667  0.571429  1.0  0.616438   0.741910   0.361663
# ...        ...       ...  ...       ...        ...        ...
# 5211  1.000000  0.142857  0.0  0.616438   0.047235   0.734593
# 5212  1.000000  0.142857  0.0  0.616438   0.047235   0.300520
# 5213  1.000000  0.142857  0.0  0.616438   0.047235   0.369577
# 5214  1.000000  0.142857  0.0  0.616438   0.047235   0.633118
# 5215  1.000000  0.142857  0.0  0.616438   0.047235   0.342814
#
# [5216 rows x 6 columns]

# %% [markdown]
# ## Pandas series to Numpy arrays

# %%
numpy_X = features[['SW','MWCO', 'CA', 'ZP']].to_numpy()
numpy_X[:5]
# Out:
# array([[0.45466716, 0.57142857, 1.        , 0.61643836],
#        [0.45466716, 0.57142857, 1.        , 0.61643836],
#        [0.45466716, 0.57142857, 1.        , 0.61643836],
#        [0.45466716, 0.57142857, 1.        , 0.61643836],
#        [0.45466716, 0.57142857, 1.        , 0.61643836]])

# %%
numpy_y = y.to_numpy()
numpy_y[:5]
# Out:
# array([48.05898411, 48.05898411, 48.05898411, 48.05898411, 48.05898411])

# %% [markdown]
# ## Create a train (80%) and a test (20%) set

# %%
train_X, test_X, train_y, test_y = train_test_split(numpy_X, numpy_y, test_size=0.20, random_state=0)

# %% [markdown]
# ## Numpy arrays to Pytorch tensors train

# %%
# this is for the train set.
tensor_X = torch.from_numpy(train_X).float() 
tensor_y = torch.from_numpy(train_y).float() 
print(tensor_X.shape, tensor_y.shape)
# Out:
# torch.Size([4172, 4]) torch.Size([4172])

# %%
tensor_y = tensor_y.unsqueeze(1)
print(tensor_X.shape, tensor_y.shape)
# Out:
# torch.Size([4172, 4]) torch.Size([4172, 1, 1])

# %%
torch_dataset = Data.TensorDataset(tensor_X, tensor_y)

# %% [markdown]
# ## Define a dataloader to load it in batches

# %%
total_samples = 4172

# Find divisors of the total number of samples
divisors = [i for i in range(1, total_samples + 1) if total_samples % i == 0]

# Print divisors
print("Divisors of", total_samples, "are:", divisors)
batch = 149 # we will have 149 iterations in each epoch. 4172 data divided by 28 data 
           # per batch, is equal to 75 batches or iterations to complete one epoch.
# Out:
# Divisors of 4172 are: [1, 2, 4, 7, 14, 28, 149, 298, 596, 1043, 2086, 4172]

# %%
loader = Data.DataLoader(
    dataset = torch_dataset,      # torch TensorDataset format
    batch_size = batch,           # mini batch size
    shuffle=True,                 # random shuffle for training
    num_workers=2,                # subprocesses for loading data
)

# %% [markdown]
# ## Define a nn, optimizer, and loss function

# %%
model = nn.Sequential(nn.Linear(4, 20), # first layer
   nn.ReLU(),
   nn.Linear(20, 20), # second layer
   nn.ReLU(),
   nn.Linear(20, 10), # third layer
   nn.ReLU(),
   nn.Linear(10, 10), # fourth layer
   nn.ReLU(),
   nn.Linear(10, 1), # fifth layer
   )

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.005)
loss_function = torch.nn.MSELoss()

# %% [markdown]
# ## Train our Artificial Neural Network

# %%
loss_lst = []
for epoch in range(1, 101):
    batch = 1
    print("Epoch", epoch)
    for step, (batch_x, batch_y) in enumerate(loader): 
        var_X, var_y = Variable(batch_x), Variable(batch_y)
        prediction = model(var_X)
        rmse_loss = torch.sqrt(loss_function(prediction, var_y))

        optimizer.zero_grad()
        rmse_loss.backward()
        optimizer.step()
        
        loss_lst.append(float(rmse_loss))
        print("Batch: ", batch, ", loss: ", rmse_loss)
        batch += 1
    print("Result of the last epoch's batch: ", rmse_loss)
    print(' ')
# Out:
# r(6.0815, grad_fn=<SqrtBackward0>)
# Batch:  20 , loss:  tensor(8.5627, grad_fn=<SqrtBackward0>)
# Batch:  21 , loss:  tensor(7.6097, grad_fn=<SqrtBackward0>)
# Batch:  22 , loss:  tensor(10.0153, grad_fn=<SqrtBackward0>)
# Batch:  23 , loss:  tensor(6.6966, grad_fn=<SqrtBackward0>)
# Batch:  24 , loss:  tensor(6.6151, grad_fn=<SqrtBackward0>)
# Batch:  25 , loss:  tensor(7.3194, grad_fn=<SqrtBackward0>)
# Batch:  26 , loss:  tensor(6.3109, grad_fn=<SqrtBackward0>)
# Batch:  27 , loss:  tensor(8.3447, grad_fn=<SqrtBackward0>)
# Batch:  28 , loss:  tensor(6.1823, grad_fn=<SqrtBackward0>)
# Result of the last epoch's batch:  tensor(6.1823, grad_fn=<SqrtBackward0>)
#
# Epoch 90
# Batch:  1 , loss:  tensor(10.0384, grad_fn=<SqrtBackward0>)
# Batch:  2 , loss:  tensor(6.8819, grad_fn=<SqrtBackward0>)
# Batch:  3 , loss:  tensor(7.5602, grad_fn=<SqrtBackward0>)
# Batch:  4 , loss:  tensor(8.7305, grad_fn=<SqrtBackward0>)
# Batch:  5 , loss:  tensor(8.7426, grad_fn=<SqrtBackward0>)
# Batch:  6 , loss:  tensor(8.4679, grad_fn=<SqrtBackward0>)
# Batch:  7 , loss:  tensor(8.2755, grad_fn=<SqrtBackward0>)
# Batch:  8 , loss:  tensor(7.7196, grad_fn=<SqrtBackward0>)
# Batch:  9 , loss:  tensor(5.4011, grad_fn=<SqrtBackward0>)
# Batch:  10 , loss:  tensor(6.9952, grad_fn=<SqrtBackward0>)
# Batch:  11 , loss:  tensor(8.1915, grad_fn=<SqrtBackward0>)
# Batch:  12 , loss:  tensor(10.3042, grad_fn=<SqrtBackward0>)
# Batch:  13 , loss:  tensor(8.2109, grad_fn=<SqrtBackward0>)
# Batch:  14 , loss:  tensor(6.1584, grad_fn=<SqrtBackward0>)
# Batch:  15 , loss:  tensor(7.5948, grad_fn=<SqrtBackward0>)
# Batch:  16 , loss:  tensor(5.9434, grad_fn=<SqrtBackward0>)
# Batch:  17 , loss:  tensor(4.5228, grad_fn=<SqrtBackward0>)
# Batch:  18 , loss:  tensor(6.9833, grad_fn=<SqrtBackward0>)
# Batch:  19 , loss:  tensor(7.4672, grad_fn=<SqrtBackward0>)
# Batch:  20 , loss:  tensor(7.5829, grad_fn=<SqrtBackward0>)
# Batch:  21 , loss:  tensor(7.9000, grad_fn=<SqrtBackward0>)
# Batch:  22 , loss:  tensor(7.1258, grad_fn=<SqrtBackward0>)
# Batch:  23 , loss:  tensor(5.4416, grad_fn=<SqrtBackward0>)
# Batch:  24 , loss:  tensor(8.1060, grad_fn=<SqrtBackward0>)
# Batch:  25 , loss:  tensor(9.1675, grad_fn=<SqrtBackward0>)
# Batch:  26 , loss:  tensor(7.0975, grad_fn=<SqrtBackward0>)
# Batch:  27 , loss:  tensor(4.9188, grad_fn=<SqrtBackward0>)
# Batch:  28 , loss:  tensor(5.0754, grad_fn=<SqrtBackward0>)
# Result of the last epoch's batch:  tensor(5.0754, grad_fn=<SqrtBackward0>)
#
# Epoch 91
# Batch:  1 , loss:  tensor(6.2706, grad_fn=<SqrtBackward0>)
# Batch:  2 , loss:  tensor(9.7452, grad_fn=<SqrtBackward0>)
# Batch:  3 , loss:  tensor(6.9133, grad_fn=<SqrtBackward0>)
# Batch:  4 , loss:  tensor(7.3687, grad_fn=<SqrtBackward0>)
# Batch:  5 , loss:  tensor(6.4647, grad_fn=<SqrtBackward0>)
# Batch:  6 , loss:  tensor(6.4900, grad_fn=<SqrtBackward0>)
# Batch:  7 , loss:  tensor(8.1961, grad_fn=<SqrtBackward0>)
# Batch:  8 , loss:  tensor(6.7204, grad_fn=<SqrtBackward0>)
# Batch:  9 , loss:  tensor(9.4868, grad_fn=<SqrtBackward0>)
# Batch:  10 , loss:  tensor(6.3505, grad_fn=<SqrtBackward0>)
# Batch:  11 , loss:  tensor(5.6154, grad_fn=<SqrtBackward0>)
# Batch:  12 , loss:  tensor(10.8831, grad_fn=<SqrtBackward0>)
# Batch:  13 , loss:  tensor(6.9342, grad_fn=<SqrtBackward0>)
# Batch:  14 , loss:  tensor(6.6000, grad_fn=<SqrtBackward0>)
# Batch:  15 , loss:  tensor(4.9293, grad_fn=<SqrtBackward0>)
# Batch:  16 , loss:  tensor(6.6161, grad_fn=<SqrtBackward0>)
# Batch:  17 , loss:  tensor(7.0447, grad_fn=<SqrtBackward0>)
# Batch:  18 , loss:  tensor(7.6273, grad_fn=<SqrtBackward0>)
# Batch:  19 , loss:  tensor(6.5440, grad_fn=<SqrtBackward0>)
# Batch:  20 , loss:  tensor(8.2408, grad_fn=<SqrtBackward0>)
# Batch:  21 , loss:  tensor(5.8553, grad_fn=<SqrtBackward0>)
# Batch:  22 , loss:  tensor(7.3944, grad_fn=<SqrtBackward0>)
# Batch:  23 , loss:  tensor(9.6134, grad_fn=<SqrtBackward0>)
# Batch:  24 , loss:  tensor(7.5200, grad_fn=<SqrtBackward0>)
# Batch:  25 , loss:  tensor(6.5355, grad_fn=<SqrtBackward0>)
# Batch:  26 , loss:  tensor(9.7943, grad_fn=<SqrtBackward0>)
# Batch:  27 , loss:  tensor(6.9193, grad_fn=<SqrtBackward0>)
# Batch:  28 , loss:  tensor(8.8171, grad_fn=<SqrtBackward0>)
# Result of the last epoch's batch:  tensor(8.8171, grad_fn=<SqrtBackward0>)
#
# Epoch 92
# Batch:  1 , loss:  tensor(7.2650, grad_fn=<SqrtBackward0>)
# Batch:  2 , loss:  tensor(9.1689, grad_fn=<SqrtBackward0>)
# Batch:  3 , loss:  tensor(7.7065, grad_fn=<SqrtBackward0>)
# Batch:  4 , loss:  tensor(10.3984, grad_fn=<SqrtBackward0>)
# Batch:  5 , loss:  tensor(8.7098, grad_fn=<SqrtBackward0>)
# Batch:  6 , loss:  tensor(5.8267, grad_fn=<SqrtBackward0>)
# Batch:  7 , loss:  tensor(8.9949, grad_fn=<SqrtBackward0>)
# Batch:  8 , loss:  tensor(7.0092, grad_fn=<SqrtBackward0>)
# Batch:  9 , loss:  tensor(7.0836, grad_fn=<SqrtBackward0>)
# Batch:  10 , loss:  tensor(7.5170, grad_fn=<SqrtBackward0>)
# Batch:  11 , loss:  tensor(7.1391, grad_fn=<SqrtBackward0>)
# Batch:  12 , loss:  tensor(8.2751, grad_fn=<SqrtBackward0>)
# Batch:  13 , loss:  tensor(9.4547, grad_fn=<SqrtBackward0>)
# Batch:  14 , loss:  tensor(6.2307, grad_fn=<SqrtBackward0>)
# Batch:  15 , loss:  tensor(3.6365, grad_fn=<SqrtBackward0>)
# Batch:  16 , loss:  tensor(9.1190, grad_fn=<SqrtBackward0>)
# Batch:  17 , loss:  tensor(4.9857, grad_fn=<SqrtBackward0>)
# Batch:  18 , loss:  tensor(6.4784, grad_fn=<SqrtBackward0>)
# Batch:  19 , loss:  tensor(2.6432, grad_fn=<SqrtBackward0>)
# Batch:  20 , loss:  tensor(3.4440, grad_fn=<SqrtBackward0>)
# Batch:  21 , loss:  tensor(7.4291, grad_fn=<SqrtBackward0>)
# Batch:  22 , loss:  tensor(9.8730, grad_fn=<SqrtBackward0>)
# Batch:  23 , loss:  tensor(8.0873, grad_fn=<SqrtBackward0>)
# Batch:  24 , loss:  tensor(10.0792, grad_fn=<SqrtBackward0>)
# Batch:  25 , loss:  tensor(10.9874, grad_fn=<SqrtBackward0>)
# Batch:  26 , loss:  tensor(7.1490, grad_fn=<SqrtBackward0>)
# Batch:  27 , loss:  tensor(8.3148, grad_fn=<SqrtBackward0>)
# Batch:  28 , loss:  tensor(5.7962, grad_fn=<SqrtBackward0>)
# Result of the last epoch's batch:  tensor(5.7962, grad_fn=<SqrtBackward0>)
#
# Epoch 93
# Batch:  1 , loss:  tensor(7.9853, grad_fn=<SqrtBackward0>)
# Batch:  2 , loss:  tensor(8.1673, grad_fn=<SqrtBackward0>)
# Batch:  3 , loss:  tensor(6.9603, grad_fn=<SqrtBackward0>)
# Batch:  4 , loss:  tensor(6.5346, grad_fn=<SqrtBackward0>)
# Batch:  5 , loss:  tensor(5.8269, grad_fn=<SqrtBackward0>)
# Batch:  6 , loss:  tensor(8.6353, grad_fn=<SqrtBackward0>)
# Batch:  7 , loss:  tensor(9.3254, grad_fn=<SqrtBackward0>)
# Batch:  8 , loss:  tensor(7.4115, grad_fn=<SqrtBackward0>)
# Batch:  9 , loss:  tensor(8.4155, grad_fn=<SqrtBackward0>)
# Batch:  10 , loss:  tensor(9.1367, grad_fn=<SqrtBackward0>)
# Batch:  11 , loss:  tensor(8.4027, grad_fn=<SqrtBackward0>)
# Batch:  12 , loss:  tensor(7.9570, grad_fn=<SqrtBackward0>)
# Batch:  13 , loss:  tensor(7.7334, grad_fn=<SqrtBackward0>)
# Batch:  14 , loss:  tensor(5.5315, grad_fn=<SqrtBackward0>)
# Batch:  15 , loss:  tensor(8.6238, grad_fn=<SqrtBackward0>)
# Batch:  16 , loss:  tensor(6.6049, grad_fn=<SqrtBackward0>)
# Batch:  17 , loss:  tensor(6.5702, grad_fn=<SqrtBackward0>)
# Batch:  18 , loss:  tensor(5.8358, grad_fn=<SqrtBackward0>)
# Batch:  19 , loss:  tensor(7.2760, grad_fn=<SqrtBackward0>)
# Batch:  20 , loss:  tensor(8.7369, grad_fn=<SqrtBackward0>)
# Batch:  21 , loss:  tensor(8.0680, grad_fn=<SqrtBackward0>)
# Batch:  22 , loss:  tensor(8.0900, grad_fn=<SqrtBackward0>)
# Batch:  23 , loss:  tensor(6.1314, grad_fn=<SqrtBackward0>)
# Batch:  24 , loss:  tensor(9.9028, grad_fn=<SqrtBackward0>)
# Batch:  25 , loss:  tensor(7.7219, grad_fn=<SqrtBackward0>)
# Batch:  26 , loss:  tensor(5.4611, grad_fn=<SqrtBackward0>)
# Batch:  27 , loss:  tensor(6.4671, grad_fn=<SqrtBackward0>)
# Batch:  28 , loss:  tensor(9.6090, grad_fn=<SqrtBackward0>)
# Result of the last epoch's batch:  tensor(9.6090, grad_fn=<SqrtBackward0>)
#
# Epoch 94
# Batch:  1 , loss:  tensor(7.8040, grad_fn=<SqrtBackward0>)
# Batch:  2 , loss:  tensor(8.0767, grad_fn=<SqrtBackward0>)
# Batch:  3 , loss:  tensor(6.9811, grad_fn=<SqrtBackward0>)
# Batch:  4 , loss:  tensor(7.6183, grad_fn=<SqrtBackward0>)
# Batch:  5 , loss:  tensor(8.0180, grad_fn=<SqrtBackward0>)
# Batch:  6 , loss:  tensor(6.8871, grad_fn=<SqrtBackward0>)
# Batch:  7 , loss:  tensor(4.2650, grad_fn=<SqrtBackward0>)
# Batch:  8 , loss:  tensor(6.4815, grad_fn=<SqrtBackward0>)
# Batch:  9 , loss:  tensor(9.1186, grad_fn=<SqrtBackward0>)
# Batch:  10 , loss:  tensor(8.5104, grad_fn=<SqrtBackward0>)
# Batch:  11 , loss:  tensor(6.5018, grad_fn=<SqrtBackward0>)
# Batch:  12 , loss:  tensor(9.0854, grad_fn=<SqrtBackward0>)
# Batch:  13 , loss:  tensor(8.4902, grad_fn=<SqrtBackward0>)
# Batch:  14 , loss:  tensor(9.0822, grad_fn=<SqrtBackward0>)
# Batch:  15 , loss:  tensor(7.7841, grad_fn=<SqrtBackward0>)
# Batch:  16 , loss:  tensor(7.5594, grad_fn=<SqrtBackward0>)
# Batch:  17 , loss:  tensor(6.8968, grad_fn=<SqrtBackward0>)
# Batch:  18 , loss:  tensor(7.3661, grad_fn=<SqrtBackward0>)
# Batch:  19 , loss:  tensor(5.6830, grad_fn=<SqrtBackward0>)
# Batch:  20 , loss:  tensor(3.8270, grad_fn=<SqrtBackward0>)
# Batch:  21 , loss:  tensor(5.4762, grad_fn=<SqrtBackward0>)
# Batch:  22 , loss:  tensor(6.2546, grad_fn=<SqrtBackward0>)
# Batch:  23 , loss:  tensor(10.0436, grad_fn=<SqrtBackward0>)
# Batch:  24 , loss:  tensor(7.0299, grad_fn=<SqrtBackward0>)
# Batch:  25 , loss:  tensor(10.5997, grad_fn=<SqrtBackward0>)
# Batch:  26 , loss:  tensor(6.8864, grad_fn=<SqrtBackward0>)
# Batch:  27 , loss:  tensor(8.8889, grad_fn=<SqrtBackward0>)
# Batch:  28 , loss:  tensor(7.2170, grad_fn=<SqrtBackward0>)
# Result of the last epoch's batch:  tensor(7.2170, grad_fn=<SqrtBackward0>)
#
# Epoch 95
# Batch:  1 , loss:  tensor(6.9839, grad_fn=<SqrtBackward0>)
# Batch:  2 , loss:  tensor(7.4496, grad_fn=<SqrtBackward0>)
# Batch:  3 , loss:  tensor(8.4303, grad_fn=<SqrtBackward0>)
# Batch:  4 , loss:  tensor(6.7505, grad_fn=<SqrtBackward0>)
# Batch:  5 , loss:  tensor(4.5684, grad_fn=<SqrtBackward0>)
# Batch:  6 , loss:  tensor(5.2259, grad_fn=<SqrtBackward0>)
# Batch:  7 , loss:  tensor(9.1343, grad_fn=<SqrtBackward0>)
# Batch:  8 , loss:  tensor(9.2601, grad_fn=<SqrtBackward0>)
# Batch:  9 , loss:  tensor(8.6038, grad_fn=<SqrtBackward0>)
# Batch:  10 , loss:  tensor(9.2543, grad_fn=<SqrtBackward0>)
# Batch:  11 , loss:  tensor(9.5286, grad_fn=<SqrtBackward0>)
# Batch:  12 , loss:  tensor(6.4714, grad_fn=<SqrtBackward0>)
# Batch:  13 , loss:  tensor(6.6834, grad_fn=<SqrtBackward0>)
# Batch:  14 , loss:  tensor(10.0894, grad_fn=<SqrtBackward0>)
# Batch:  15 , loss:  tensor(6.5873, grad_fn=<SqrtBackward0>)
# Batch:  16 , loss:  tensor(5.5043, grad_fn=<SqrtBackward0>)
# Batch:  17 , loss:  tensor(6.2265, grad_fn=<SqrtBackward0>)
# Batch:  18 , loss:  tensor(4.4024, grad_fn=<SqrtBackward0>)
# Batch:  19 , loss:  tensor(6.3340, grad_fn=<SqrtBackward0>)
# Batch:  20 , loss:  tensor(7.0469, grad_fn=<SqrtBackward0>)
# Batch:  21 , loss:  tensor(7.2315, grad_fn=<SqrtBackward0>)
# Batch:  22 , loss:  tensor(9.8201, grad_fn=<SqrtBackward0>)
# Batch:  23 , loss:  tensor(6.7794, grad_fn=<SqrtBackward0>)
# Batch:  24 , loss:  tensor(8.0078, grad_fn=<SqrtBackward0>)
# Batch:  25 , loss:  tensor(7.2924, grad_fn=<SqrtBackward0>)
# Batch:  26 , loss:  tensor(9.1843, grad_fn=<SqrtBackward0>)
# Batch:  27 , loss:  tensor(7.8433, grad_fn=<SqrtBackward0>)
# Batch:  28 , loss:  tensor(7.0218, grad_fn=<SqrtBackward0>)
# Result of the last epoch's batch:  tensor(7.0218, grad_fn=<SqrtBackward0>)
#
# Epoch 96
# Batch:  1 , loss:  tensor(7.3144, grad_fn=<SqrtBackward0>)
# Batch:  2 , loss:  tensor(7.0271, grad_fn=<SqrtBackward0>)
# Batch:  3 , loss:  tensor(9.3270, grad_fn=<SqrtBackward0>)
# Batch:  4 , loss:  tensor(8.0380, grad_fn=<SqrtBackward0>)
# Batch:  5 , loss:  tensor(8.1823, grad_fn=<SqrtBackward0>)
# Batch:  6 , loss:  tensor(7.3229, grad_fn=<SqrtBackward0>)
# Batch:  7 , loss:  tensor(7.1195, grad_fn=<SqrtBackward0>)
# Batch:  8 , loss:  tensor(9.0859, grad_fn=<SqrtBackward0>)
# Batch:  9 , loss:  tensor(7.9013, grad_fn=<SqrtBackward0>)
# Batch:  10 , loss:  tensor(7.1486, grad_fn=<SqrtBackward0>)
# Batch:  11 , loss:  tensor(9.3679, grad_fn=<SqrtBackward0>)
# Batch:  12 , loss:  tensor(7.1599, grad_fn=<SqrtBackward0>)
# Batch:  13 , loss:  tensor(6.4877, grad_fn=<SqrtBackward0>)
# Batch:  14 , loss:  tensor(5.4636, grad_fn=<SqrtBackward0>)
# Batch:  15 , loss:  tensor(3.7755, grad_fn=<SqrtBackward0>)
# Batch:  16 , loss:  tensor(8.1969, grad_fn=<SqrtBackward0>)
# Batch:  17 , loss:  tensor(5.1618, grad_fn=<SqrtBackward0>)
# Batch:  18 , loss:  tensor(3.8089, grad_fn=<SqrtBackward0>)
# Batch:  19 , loss:  tensor(10.5578, grad_fn=<SqrtBackward0>)
# Batch:  20 , loss:  tensor(5.6133, grad_fn=<SqrtBackward0>)
# Batch:  21 , loss:  tensor(8.4915, grad_fn=<SqrtBackward0>)
# Batch:  22 , loss:  tensor(7.2339, grad_fn=<SqrtBackward0>)
# Batch:  23 , loss:  tensor(10.0575, grad_fn=<SqrtBackward0>)
# Batch:  24 , loss:  tensor(11.3616, grad_fn=<SqrtBackward0>)
# Batch:  25 , loss:  tensor(4.9902, grad_fn=<SqrtBackward0>)
# Batch:  26 , loss:  tensor(9.9228, grad_fn=<SqrtBackward0>)
# Batch:  27 , loss:  tensor(6.2309, grad_fn=<SqrtBackward0>)
# Batch:  28 , loss:  tensor(7.7364, grad_fn=<SqrtBackward0>)
# Result of the last epoch's batch:  tensor(7.7364, grad_fn=<SqrtBackward0>)
#
# Epoch 97
# Batch:  1 , loss:  tensor(8.6724, grad_fn=<SqrtBackward0>)
# Batch:  2 , loss:  tensor(5.9073, grad_fn=<SqrtBackward0>)
# Batch:  3 , loss:  tensor(9.6466, grad_fn=<SqrtBackward0>)
# Batch:  4 , loss:  tensor(10.4198, grad_fn=<SqrtBackward0>)
# Batch:  5 , loss:  tensor(4.8449, grad_fn=<SqrtBackward0>)
# Batch:  6 , loss:  tensor(6.3096, grad_fn=<SqrtBackward0>)
# Batch:  7 , loss:  tensor(5.2231, grad_fn=<SqrtBackward0>)
# Batch:  8 , loss:  tensor(9.1054, grad_fn=<SqrtBackward0>)
# Batch:  9 , loss:  tensor(4.5107, grad_fn=<SqrtBackward0>)
# Batch:  10 , loss:  tensor(6.5313, grad_fn=<SqrtBackward0>)
# Batch:  11 , loss:  tensor(6.3874, grad_fn=<SqrtBackward0>)
# Batch:  12 , loss:  tensor(7.3064, grad_fn=<SqrtBackward0>)
# Batch:  13 , loss:  tensor(8.9398, grad_fn=<SqrtBackward0>)
# Batch:  14 , loss:  tensor(7.3318, grad_fn=<SqrtBackward0>)
# Batch:  15 , loss:  tensor(7.2262, grad_fn=<SqrtBackward0>)
# Batch:  16 , loss:  tensor(11.0509, grad_fn=<SqrtBackward0>)
# Batch:  17 , loss:  tensor(7.5448, grad_fn=<SqrtBackward0>)
# Batch:  18 , loss:  tensor(7.9101, grad_fn=<SqrtBackward0>)
# Batch:  19 , loss:  tensor(8.9318, grad_fn=<SqrtBackward0>)
# Batch:  20 , loss:  tensor(7.7870, grad_fn=<SqrtBackward0>)
# Batch:  21 , loss:  tensor(8.8645, grad_fn=<SqrtBackward0>)
# Batch:  22 , loss:  tensor(6.2215, grad_fn=<SqrtBackward0>)
# Batch:  23 , loss:  tensor(8.0025, grad_fn=<SqrtBackward0>)
# Batch:  24 , loss:  tensor(6.8080, grad_fn=<SqrtBackward0>)
# Batch:  25 , loss:  tensor(8.1458, grad_fn=<SqrtBackward0>)
# Batch:  26 , loss:  tensor(7.8482, grad_fn=<SqrtBackward0>)
# Batch:  27 , loss:  tensor(6.0128, grad_fn=<SqrtBackward0>)
# Batch:  28 , loss:  tensor(6.4728, grad_fn=<SqrtBackward0>)
# Result of the last epoch's batch:  tensor(6.4728, grad_fn=<SqrtBackward0>)
#
# Epoch 98
# Batch:  1 , loss:  tensor(5.4040, grad_fn=<SqrtBackward0>)
# Batch:  2 , loss:  tensor(7.2492, grad_fn=<SqrtBackward0>)
# Batch:  3 , loss:  tensor(8.9913, grad_fn=<SqrtBackward0>)
# Batch:  4 , loss:  tensor(8.2497, grad_fn=<SqrtBackward0>)
# Batch:  5 , loss:  tensor(9.1485, grad_fn=<SqrtBackward0>)
# Batch:  6 , loss:  tensor(6.7775, grad_fn=<SqrtBackward0>)
# Batch:  7 , loss:  tensor(5.5374, grad_fn=<SqrtBackward0>)
# Batch:  8 , loss:  tensor(7.8988, grad_fn=<SqrtBackward0>)
# Batch:  9 , loss:  tensor(7.8062, grad_fn=<SqrtBackward0>)
# Batch:  10 , loss:  tensor(10.3584, grad_fn=<SqrtBackward0>)
# Batch:  11 , loss:  tensor(8.0229, grad_fn=<SqrtBackward0>)
# Batch:  12 , loss:  tensor(4.0168, grad_fn=<SqrtBackward0>)
# Batch:  13 , loss:  tensor(9.5933, grad_fn=<SqrtBackward0>)
# Batch:  14 , loss:  tensor(6.8927, grad_fn=<SqrtBackward0>)
# Batch:  15 , loss:  tensor(8.5060, grad_fn=<SqrtBackward0>)
# Batch:  16 , loss:  tensor(7.9177, grad_fn=<SqrtBackward0>)
# Batch:  17 , loss:  tensor(4.3075, grad_fn=<SqrtBackward0>)
# Batch:  18 , loss:  tensor(10.0812, grad_fn=<SqrtBackward0>)
# Batch:  19 , loss:  tensor(8.2795, grad_fn=<SqrtBackward0>)
# Batch:  20 , loss:  tensor(6.9135, grad_fn=<SqrtBackward0>)
# Batch:  21 , loss:  tensor(7.0580, grad_fn=<SqrtBackward0>)
# Batch:  22 , loss:  tensor(7.3660, grad_fn=<SqrtBackward0>)
# Batch:  23 , loss:  tensor(7.1362, grad_fn=<SqrtBackward0>)
# Batch:  24 , loss:  tensor(6.4210, grad_fn=<SqrtBackward0>)
# Batch:  25 , loss:  tensor(6.5580, grad_fn=<SqrtBackward0>)
# Batch:  26 , loss:  tensor(8.3570, grad_fn=<SqrtBackward0>)
# Batch:  27 , loss:  tensor(7.9954, grad_fn=<SqrtBackward0>)
# Batch:  28 , loss:  tensor(6.6578, grad_fn=<SqrtBackward0>)
# Result of the last epoch's batch:  tensor(6.6578, grad_fn=<SqrtBackward0>)
#
# Epoch 99
# Batch:  1 , loss:  tensor(9.4106, grad_fn=<SqrtBackward0>)
# Batch:  2 , loss:  tensor(9.3883, grad_fn=<SqrtBackward0>)
# Batch:  3 , loss:  tensor(7.2288, grad_fn=<SqrtBackward0>)
# Batch:  4 , loss:  tensor(6.6647, grad_fn=<SqrtBackward0>)
# Batch:  5 , loss:  tensor(6.7303, grad_fn=<SqrtBackward0>)
# Batch:  6 , loss:  tensor(7.3332, grad_fn=<SqrtBackward0>)
# Batch:  7 , loss:  tensor(7.1097, grad_fn=<SqrtBackward0>)
# Batch:  8 , loss:  tensor(7.9399, grad_fn=<SqrtBackward0>)
# Batch:  9 , loss:  tensor(7.4318, grad_fn=<SqrtBackward0>)
# Batch:  10 , loss:  tensor(5.9280, grad_fn=<SqrtBackward0>)
# Batch:  11 , loss:  tensor(6.2304, grad_fn=<SqrtBackward0>)
# Batch:  12 , loss:  tensor(5.1222, grad_fn=<SqrtBackward0>)
# Batch:  13 , loss:  tensor(7.0966, grad_fn=<SqrtBackward0>)
# Batch:  14 , loss:  tensor(6.5583, grad_fn=<SqrtBackward0>)
# Batch:  15 , loss:  tensor(8.8086, grad_fn=<SqrtBackward0>)
# Batch:  16 , loss:  tensor(8.8581, grad_fn=<SqrtBackward0>)
# Batch:  17 , loss:  tensor(6.3510, grad_fn=<SqrtBackward0>)
# Batch:  18 , loss:  tensor(8.1782, grad_fn=<SqrtBackward0>)
# Batch:  19 , loss:  tensor(5.7048, grad_fn=<SqrtBackward0>)
# Batch:  20 , loss:  tensor(4.9678, grad_fn=<SqrtBackward0>)
# Batch:  21 , loss:  tensor(7.7944, grad_fn=<SqrtBackward0>)
# Batch:  22 , loss:  tensor(6.9936, grad_fn=<SqrtBackward0>)
# Batch:  23 , loss:  tensor(6.2781, grad_fn=<SqrtBackward0>)
# Batch:  24 , loss:  tensor(8.2723, grad_fn=<SqrtBackward0>)
# Batch:  25 , loss:  tensor(8.7694, grad_fn=<SqrtBackward0>)
# Batch:  26 , loss:  tensor(7.5268, grad_fn=<SqrtBackward0>)
# Batch:  27 , loss:  tensor(10.1203, grad_fn=<SqrtBackward0>)
# Batch:  28 , loss:  tensor(10.0648, grad_fn=<SqrtBackward0>)
# Result of the last epoch's batch:  tensor(10.0648, grad_fn=<SqrtBackward0>)
#
# Epoch 100
# Batch:  1 , loss:  tensor(8.4952, grad_fn=<SqrtBackward0>)
# Batch:  2 , loss:  tensor(4.9849, grad_fn=<SqrtBackward0>)
# Batch:  3 , loss:  tensor(7.5846, grad_fn=<SqrtBackward0>)
# Batch:  4 , loss:  tensor(6.6880, grad_fn=<SqrtBackward0>)
# Batch:  5 , loss:  tensor(8.3406, grad_fn=<SqrtBackward0>)
# Batch:  6 , loss:  tensor(7.1740, grad_fn=<SqrtBackward0>)
# Batch:  7 , loss:  tensor(7.1886, grad_fn=<SqrtBackward0>)
# Batch:  8 , loss:  tensor(8.1647, grad_fn=<SqrtBackward0>)
# Batch:  9 , loss:  tensor(6.5450, grad_fn=<SqrtBackward0>)
# Batch:  10 , loss:  tensor(9.3960, grad_fn=<SqrtBackward0>)
# Batch:  11 , loss:  tensor(8.4461, grad_fn=<SqrtBackward0>)
# Batch:  12 , loss:  tensor(7.9529, grad_fn=<SqrtBackward0>)
# Batch:  13 , loss:  tensor(6.0070, grad_fn=<SqrtBackward0>)
# Batch:  14 , loss:  tensor(6.4047, grad_fn=<SqrtBackward0>)
# Batch:  15 , loss:  tensor(6.4868, grad_fn=<SqrtBackward0>)
# Batch:  16 , loss:  tensor(7.5054, grad_fn=<SqrtBackward0>)
# Batch:  17 , loss:  tensor(8.6240, grad_fn=<SqrtBackward0>)
# Batch:  18 , loss:  tensor(4.8812, grad_fn=<SqrtBackward0>)
# Batch:  19 , loss:  tensor(8.4009, grad_fn=<SqrtBackward0>)
# Batch:  20 , loss:  tensor(6.5883, grad_fn=<SqrtBackward0>)
# Batch:  21 , loss:  tensor(7.8657, grad_fn=<SqrtBackward0>)
# Batch:  22 , loss:  tensor(7.1480, grad_fn=<SqrtBackward0>)
# Batch:  23 , loss:  tensor(7.9023, grad_fn=<SqrtBackward0>)
# Batch:  24 , loss:  tensor(9.3936, grad_fn=<SqrtBackward0>)
# Batch:  25 , loss:  tensor(6.1709, grad_fn=<SqrtBackward0>)
# Batch:  26 , loss:  tensor(7.2216, grad_fn=<SqrtBackward0>)
# Batch:  27 , loss:  tensor(9.5344, grad_fn=<SqrtBackward0>)
# Batch:  28 , loss:  tensor(7.8778, grad_fn=<SqrtBackward0>)
# Result of the last epoch's batch:  tensor(7.8778, grad_fn=<SqrtBackward0>)

# %%
# Save the model state dictionary
torch.save(model.state_dict(), 'models/StateMlPres2.pth')

# Save the entire model
torch.save(model, 'models/MlPres2.pth')

# %%
#Load the Saved Model
model = torch.load('models/MlPres2.pth')
model.load_state_dict(torch.load('models/StateMlPres2.pth'))
model.eval()
# Out:
# Sequential(
#   (0): Linear(in_features=4, out_features=20, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=20, out_features=20, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=20, out_features=10, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=10, out_features=10, bias=True)
#   (7): ReLU()
#   (8): Linear(in_features=10, out_features=1, bias=True)
# )

# %% [markdown]
# ## Plot the loss per epoch in training

# %%
plt.figure(figsize=(18,3)) 
plt.plot(loss_lst, c='red')
plt.show()

# %% [markdown]
# ## Test our Artificial Neural Network

# %% [markdown]
# **Convert Numpy arrays to Pytorch tensors for testing set.**

# %%
# this is for the test set.
tensor_X_test = torch.from_numpy(test_X).float() 
tensor_y_test = torch.from_numpy(test_y).float() 
print(tensor_X_test.shape, tensor_y_test.shape)

tensor_y_test = tensor_y_test.unsqueeze(1)
print(tensor_X_test.shape, tensor_y_test.shape)
# Out:
# torch.Size([1044, 4]) torch.Size([1044])
# torch.Size([1044, 4]) torch.Size([1044, 1])

# %%
var_X_test = Variable(tensor_X_test)
var_y_test = Variable(tensor_y_test)
print(var_y_test)
# Out:
# tensor([[1.5400],
#         [0.7475],
#         [1.3624],
#         ...,
#         [0.8100],
#         [3.6772],
#         [0.7475]])

# %% [markdown]
# **Do predictions of the testing set and calculate the RMSE.**

# %%
with torch.no_grad():
 predictions = model(var_X_test)

# %%
# Calculate prediction accuracy
correct = (predictions.argmax(dim=1) == var_y_test).sum().item()
total += var_y_test.size(0)
accuracy = correct / total
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.0

# %%
# Plot the prediction accuracy
plt.figure(figsize=(8, 6))
plt.bar(['Correct', 'Incorrect'], [correct, total - correct], color=['green', 'red'])
plt.xlabel('Prediction')
plt.ylabel('Count')
plt.title('Prediction Accuracy')
plt.show()

# %%
y_pred = predictions.tolist()
y_real = var_y_test.tolist()

# %%
# Save predictions as a CSV file
predictions_df = pd.DataFrame({'Actual': y_real, 'Predicted': y_pred})
predictions_df.to_csv('MLPRerneance.csv', index=False)

#Save to Excel
dframe = pd.DataFrame({'GroundTruth': var_y_test.squeeze().numpy(),
                       'Prediction': predictions.squeeze()})
dframe.to_excel('MLPRerneance.xlsx', index=True)

# %%
rmse_loss = torch.sqrt(loss_function(predictions, var_y_test))

# %%
rmse_loss
# Out:
# tensor(8.1238)

# %% [markdown]
# ## Plot the predictions against target values

# %%
plt.figure(figsize=(18,3)) 
plt.plot(y_pred, c='blue', label="predictions")
plt.plot(y_real, c='red', label="target")
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# ## Predict JUST one data with our model

# %%
data_x = var_X_test[0]
data_x
# Out:
# tensor([0.1390, 0.4286, 0.4717, 0.0000])

# %%
prediction = model(data_x)

# %%
print("Target value: ", var_y_test[0])
print("Prediction: ", prediction)
# Out:
# Target value:  tensor([1.5400])
# Prediction:  tensor([1.2946], grad_fn=<ViewBackward0>)

# %% [markdown]
# **When predicting only one data, the first one of the testing set, it can be seen that the target or real value is 28 MPG and that the prediction is 26.7. The prediction is really close and has an absolute error of 1.3 MPG or a percentage error of 4.6%.**
